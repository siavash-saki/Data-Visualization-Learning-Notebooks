# %% [markdown]
# # Matplotlib.pyplot

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
#  <hr size="30">

# %% [markdown]
# ```python
# import matplotlib as mpl
# print(plt.style.available)
# mpl.style.use(['ggplot']) # optional: for ggplot-like style
# ```

# %% [markdown]
# ## plt.plot()
# ```python
# plt.plot(x,y)
# plt.xlabel('x axis')
# plt.ylabel('y axis')
# ```

# %% [markdown]
# ## plt.figure()
#
# ```python
# figure = plt.figure(figsize=,dpi=)
#
# axes1 = figure.add_axes ([0.1,0.1,0.9,0.9])
# axes2 = ...
#
# axes1.plot(x,y)
# axes1.set_xlabel('string')
# axes1.set_ylabel('string')
# axes1.set_title('string')
#
# axes1.set_xlim([low,high])
#
# figure.tight_layout()
# plt.show()
# ```

# %% [markdown]
# ## plt.subplots()
#
# ```python
# figure,axes = plt.subplots(nrows=,ncols=,figsize=(,),dpi=)
#
# axes[0].plot(x,y)
# axes[0].set_xlable('string')
# axes[0].set_ylable('string')
# axes[0].set_title('string')
#
# axes[1] ...
# ```

# %% [markdown]
# ## marker size and color
# ```python
# ax.plot(x, y, color="purple", lw=1, ls='-', marker='o', markersize=8,
#         markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
# ```

# %% [markdown]
# ## save
#
# ```python
# figure.savefig('name.format')
# ```

# %% [markdown]
# ## legend
#
# ```python
# axes.plot(x,y,label=)
# axes.legend()
# plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# ```

# %% [markdown]
# ----

# %%
x= np.linspace(0,2*np.pi,50)
y1= np.sin(x)
y2= np.cos(x)

plt.plot(x,y1)
plt.xlabel('x axis')
plt.ylabel('y axis')
# plt.title(Text(0.5, 1.0, 'sin(x)'))
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# -----

# %%
plt.subplot(1,2,1)
plt.plot(x,y1)
plt.subplot(1,2,2)
plt.plot(x,y2)

# %% [markdown]
# ------

# %%
fig=plt.figure()
axes= fig.add_axes([0,0,1,1])
axes.plot(x,y1)
axes.plot(x,y2,'r')
axes.set_xlabel('Set X Label')
axes.set_ylabel('Set Y Label')
axes.set_title('sin and cos')
plt.show()

# %% [markdown]
# ------

# %%
fig2=plt.figure()
axes1= fig2.add_axes([0,0,0.7,1])
axes2= fig2.add_axes([0.9,0,0.7,1])

axes1.plot(x,y1)
axes1.set_xlabel('X')
axes1.set_ylabel('Y')
axes1.set_title('sin')

axes2.plot(x,y2,'r')
axes2.set_xlabel('X')
axes2.set_ylabel('Y')
axes2.set_title('cos')

plt.show()

# %% [markdown]
# ------

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(10,5),dpi=100)
axes[0].plot(x,y1)
axes[0].set_title('sin(x)')
axes[1].plot(x,y2,'r')
axes[1].set_title('cos(x)')
fig.savefig('sin and cos.png')

# %%
np.random.seed(19680801)
data = np.random.randn(2, 100)

fig,axes=plt.subplots(2,3,figsize=(10,5),dpi=100)

axes[0][0].plot(data[0],data[1])
axes[0][1].hist(data[0])
axes[0][2].scatter(data[0],data[1])
axes[1][0].hist2d(data[0],data[1])
axes[1][1].pie([20,30,50],labels=['Dog','Cat','Mouse'])

plt.show()

# %%
dct={ 'normal': np.random.randn(1000), 'type': np.random.randint(1,5,1000)}
df= pd.DataFrame(dct)

# %%
import seaborn as sns

# %%
fig= plt.figure(figsize=(15,8))
fig.subplots_adjust(hspace=0.4, wspace=0.2)

ax1= plt.subplot(231)
sns.distplot(df[df['type']==1]['normal'],kde=False).set_title('Type 1')

ax2= plt.subplot(232)
sns.distplot(df[df['type']==2]['normal'],kde=False).set_title('Type 2')

ax3= plt.subplot(233)
sns.distplot(df[df['type']==3]['normal'],kde=False).set_title('Type 3')

ax4= plt.subplot(234)
sns.distplot(df[df['type']==4]['normal'],kde=False).set_title('Type 4')

ax5= plt.subplot(235)
sns.countplot(df['type']).set_title('Count Plot')
# Out:
# Text(0.5, 1.0, 'Count Plot')

# %% [markdown]
# ---

# %%
x=range(50,100)

dct={'Iran':x+np.random.randint(-10,11,50),
     'Irag':x+np.random.randint(-10,11,50),
     'Vietnam': x+np.random.randint(-10,11,50),
     'Russia': x+np.random.randint(-10,11,50)}

df_top4= pd.DataFrame(dct)

# %%
fig= plt.figure(figsize=(15,5))

ax1= plt.subplot(121)
df_top4.plot(kind='area', 
             stacked=True,
             ax=ax1
             )
plt.title('Immigration Trend of Top 5 Countries (Stacked)')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

ax2= plt.subplot(122)
df_top4.plot(kind='area', 
             stacked=False,
             ax=ax2
             )
plt.title('Immigration Trend of Top 5 Countries (Unstacked)')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
n = np.array([0,1,2,3,4,5])
xx = np.linspace(-0.75, 1., 100)
fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes[0].set_title("scatter")

axes[1].step(n, n**2, lw=2)
axes[1].set_title("step")

axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes[2].set_title("bar")

axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.8);
axes[3].set_title("fill_between");

# %% [markdown]
# ---

# %%
x=np.linspace(-np.pi,np.pi,365)

myfig= plt.figure(figsize=(10,6),dpi=80)
myax = myfig.add_axes([0,0,1,1])

myax.plot(x,np.sin(x),color='red',ls='--',lw=1,label='sin(x)')
myax.plot(x,np.cos(x),'g:',lw=1,label='cos(x)')

myax.set_xlim([-np.pi*1.1,np.pi*1.1])
myax.set_ylim([-1.1,1.1])

myax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
myax.set_xticklabels([r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

myax.set_yticks([-1,1])
myax.set_yticklabels([r'$-1$', r'$+1$'])


myax.spines['right'].set_color('None')
myax.spines['top'].set_color('None')

myax.xaxis.set_ticks_position('bottom')
myax.spines['bottom'].set_position(('data',0))
myax.yaxis.set_ticks_position('left')
myax.spines['left'].set_position(('data',0))

for label in myax.get_xticklabels() + myax.get_yticklabels():
    label.set_fontsize(13)

myax.legend(loc='upper left')
myax.set_aspect(1)
plt.show()

# %%
myax.get_xticklabels()
# Out:
# <a list of 5 Text xticklabel objects>

# %%
x = np.linspace(0, 5, 11)

fig, ax = plt.subplots(figsize=(12,6))

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+6, color="green", lw=3, ls='-.')

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="red", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# ----

# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
# download file and save as alice_novel.txt
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/alice_novel.txt

# open the file and read it into a variable alice_novel
alice_novel = open('alice_novel.txt', 'r').read()

# %%
stopwords = set(STOPWORDS)

# %%
# instantiate a word cloud object
alice_wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
alice_wc.generate(alice_novel)

# %%
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

# display the cloud
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
stopwords.add('said') # add the words said to stopwords

# %%
from PIL import Image # converting images into arrays

# %%
# download image
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Images/alice_mask.png
    
# save mask to alice_mask
alice_mask = np.array(Image.open('alice_mask.png'))
    
fig = plt.figure()
fig.set_figwidth(7) # set width
fig.set_figheight(9) # set height

plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# instantiate a word cloud object
alice_wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask, stopwords=stopwords)

# generate the word cloud
alice_wc.generate(alice_novel)

# display the word cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Further Reading
#
# * https://matplotlib.org/gallery/index.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
